# %%
import numpy as np

# %%
from sklearn.datasets import fetch_openml

X, y = fetch_openml('mnist_784', version=1, return_X_y=True)#, parser='auto')
X = X.values

X = X / 255. #normalization to [0,1]

y = X

print(X.shape)
print(y.shape)
# Out:
# (70000, 784)
# (70000, 784)

# %%
from sklearn.model_selection import train_test_split


X_temp, X_test, y_temp, y_test = train_test_split(
    X, y, test_size=10000, random_state=123)

X_train, X_valid, y_train, y_valid = train_test_split(
    X_temp, y_temp, test_size=5000, random_state=123)

del X_temp, y_temp, X, y

# %%
##########################
### VAE
##########################
def sigmoid(z):                                        
    return 1. / (1. + np.exp(-z))

def relu(z): #relu
    return np.maximum(0, z)

def relu_deriv(z):
    return np.where(z > 0, 1, 0)


class VAE:

    def __init__(self, input_size, hidden_size1, hidden_size2, latent_size, random_seed=123): 
        
        rng = np.random.RandomState(random_seed)
        
        # encoder weights
        self.W_e1 = rng.normal(
            loc=0.0, scale=0.1, size=(hidden_size1, input_size))
        self.b_e1 = np.zeros((1, hidden_size1))
        
        self.W_e2 = rng.normal(
            loc=0.0, scale=0.1, size=(hidden_size2, hidden_size1))
        self.b_e2 = np.zeros((1, hidden_size2))
        
        self.W_e3 = rng.normal(
            loc=0.0, scale=0.1, size=(latent_size * 2, hidden_size2))
        self.b_e3 = np.zeros((1, latent_size * 2))
        
        
        # decoder weights
        self.W_d1 = rng.normal(
            loc=0.0, scale=0.1, size=(hidden_size2, latent_size))
        self.b_d1 = np.zeros((1, hidden_size2))
        
        self.W_d2 = rng.normal(
            loc=0.0, scale=0.1, size=(hidden_size1, hidden_size2))
        self.b_d2 = np.zeros((1, hidden_size1))
        
        self.W_d3 = rng.normal(
            loc=0.0, scale=0.1, size=(input_size, hidden_size1))
        self.b_d3 = np.zeros((1, input_size))

    def encoder(self, x):
        z_e1 = x @ self.W_e1.T + self.b_e1
        a_e1 = relu(z_e1) # activation

        z_e2 = a_e1 @ self.W_e2.T + self.b_e2
        a_e2 = relu(z_e2) # activation

        mu_logvar = a_e2 @ self.W_e3.T + self.b_e3 # linear
        mu, logvar = np.split(mu_logvar, 2, axis=1)
        
        return z_e1, a_e1, z_e2, a_e2, mu, logvar
    
    def reparameterize(self, mu, logvar):
        std = np.exp(0.5 * logvar)
        eps = np.random.normal(size=mu.shape)
        
        latent = mu + eps * std
        
        return latent, eps

    def decoder(self, latent):
        z_d1 = latent @ self.W_d1.T + self.b_d1
        a_d1 = relu(z_d1) # activation
        
        z_d2 = a_d1 @ self.W_d2.T + self.b_d2
        a_d2 = relu(z_d2) # activation

        z_d3 = a_d2 @ self.W_d3.T + self.b_d3
        recon_x = sigmoid(z_d3) # sigmoid
    
        return z_d1, a_d1, z_d2, a_d2, recon_x

    def forward(self, x):
        z_e1, a_e1, z_e2, a_e2, mu, logvar = self.encoder(x)
        latent, eps = self.reparameterize(mu, logvar)
        z_d1, a_d1, z_d2, a_d2, recon_x = self.decoder(latent)
        
        return z_e1, a_e1, z_e2, a_e2, mu, logvar, latent, z_d1, a_d1, z_d2, a_d2, recon_x, eps
        
    
    def backward(self, x, z_e1, a_e1, z_e2, a_e2, mu, logvar, latent, z_d1, a_d1, z_d2, a_d2, recon_x, y, eps):
        
        # decoder backprop
        dL__dz_d3 = (recon_x - y) / y.shape[0] # only by MSE
        
        dL__dw_d3 = dL__dz_d3.T @ a_d2
        dL__db_d3 = np.sum(dL__dz_d3, axis=0)

        
        dL__da_d2 = dL__dz_d3 @ self.W_d3
        dL__dz_d2 = dL__da_d2 * relu_deriv(z_d2) # activation derivative

        dL__dw_d2 = dL__dz_d2.T @ a_d1
        dL__db_d2 = np.sum(dL__dz_d2, axis=0)

        
        dL__da_d1 = dL__dz_d2 @ self.W_d2
        dL__dz_d1 = dL__da_d1 * relu_deriv(z_d1) # activation derivative

        dL__dw_d1 = dL__dz_d1.T @ latent
        dL__db_d1 = np.sum(dL__dz_d1, axis=0)

        
        # reparameterize backprop
        dL__dlatent = dL__dz_d1 @ self.W_d1
        
        dL__dmu = dL__dlatent * 1 # gradient by CE term
        dL__dstd = dL__dlatent * eps 
        std = np.exp(0.5 * logvar)
        dL__dlogvar = dL__dstd * 0.5 * std # gradient by CE term

        dL__dmu += mu  / y.shape[0] # gradient by KL term
        dL__dlogvar += 0.5 * (np.exp(logvar) - 1) / y.shape[0] # gradient by KL term

        
        # encoder backprop
        dL__dz_e3 = np.hstack((dL__dmu, dL__dlogvar))
        
        dL__dw_e3 = dL__dz_e3.T @ a_e2
        dL__db_e3 = np.sum(dL__dz_e3, axis=0)

        
        dL__da_e2 = dL__dz_e3 @ self.W_e3
        dL__dz_e2 = dL__da_e2 * relu_deriv(z_e2) # activation derivative
        
        dL__dw_e2 = dL__dz_e2.T @ a_e1
        dL__db_e2 = np.sum(dL__dz_e2, axis=0)


        dL__da_e1 = dL__dz_e2 @ self.W_e2
        dL__dz_e1 = dL__da_e1 * relu_deriv(z_e1) # activation derivative
        
        dL__dw_e1 = dL__dz_e1.T @ x
        dL__db_e1 = np.sum(dL__dz_e1, axis=0)
        
        return dL__dw_d3, dL__db_d3, dL__dw_d2, dL__db_d2, dL__dw_d1, dL__db_d1, \
               dL__dw_e3, dL__db_e3, dL__dw_e2, dL__db_e2, dL__dw_e1, dL__db_e1

# %%
def minibatch_generator(X, y, minibatch_size): ##stable
    indices = np.arange(X.shape[0])
    np.random.shuffle(indices)

    for start_idx in range(0, indices.shape[0] - minibatch_size 
                           + 1, minibatch_size):
        batch_idx = indices[start_idx:start_idx + minibatch_size]
        
        yield X[batch_idx], y[batch_idx]

def compute_loss_mse(nnet, X, y, minibatch_size):
    loss_=0
    mse_=0
    minibatch_gen = minibatch_generator(X, y, minibatch_size)
        
    for i, (X_mini, y_mini) in enumerate(minibatch_gen):

        z_e1, a_e1, z_e2, a_e2, mu, logvar, latent, z_d1, a_d1, z_d2, a_d2, recon_x, eps = nnet.forward(X_mini)
                
        RCE = -np.sum(y_mini * np.log(recon_x) + (1 - y_mini) * np.log(1 - recon_x)) / minibatch_size # binary cross entropy loss  
        KLD = 0.5 * np.sum(np.power(mu, 2) + np.exp(logvar) - logvar - 1) / minibatch_size # KL divergence

        loss = RCE + KLD
        loss_ += loss
        
        mse = np.mean((recon_x - y_mini) ** 2)
        mse_ += mse

    loss_ /= (i+1)
    mse_ /= (i+1)
    return loss_, mse_

def train(model, X_train, y_train, X_valid, y_valid, num_epochs, minibatch_size, learning_rate):
    
    epoch_train_loss = []
    epoch_valid_loss = []
    
    for e in range(num_epochs):

        # iterate over minibatches
        minibatch_gen = minibatch_generator(
            X_train, y_train, minibatch_size)

        for X_train_mini, y_train_mini in minibatch_gen:
            
            #### Compute outputs ####
            z_e1, a_e1, z_e2, a_e2, mu, logvar, latent, z_d1, a_d1, z_d2, a_d2, recon_x, eps = model.forward(X_train_mini)

            #### Compute gradients ####
            
            dL__dw_d3, dL__db_d3, dL__dw_d2, dL__db_d2, dL__dw_d1, dL__db_d1, dL__dw_e3, dL__db_e3, dL__dw_e2, dL__db_e2, dL__dw_e1, dL__db_e1 = \
                model.backward(X_train_mini, z_e1, a_e1, z_e2, a_e2, mu, logvar, latent, z_d1, a_d1, z_d2, a_d2, recon_x, y_train_mini, eps)

            #### Update weights ####
            model.W_d1 -= learning_rate * dL__dw_d1
            model.b_d1 -= learning_rate * dL__db_d1
            model.W_d2 -= learning_rate * dL__dw_d2
            model.b_d2 -= learning_rate * dL__db_d2
            model.W_d3 -= learning_rate * dL__dw_d3
            model.b_d3 -= learning_rate * dL__db_d3
            
            model.W_e1 -= learning_rate * dL__dw_e1
            model.b_e1 -= learning_rate * dL__db_e1
            model.W_e2 -= learning_rate * dL__dw_e2
            model.b_e2 -= learning_rate * dL__db_e2
            model.W_e3 -= learning_rate * dL__dw_e3
            model.b_e3 -= learning_rate * dL__db_e3
        
        #### Epoch Logging ####        
        train_loss, train_mse = compute_loss_mse(model, X_train, y_train, minibatch_size)
        valid_loss, valid_mse = compute_loss_mse(model, X_valid, y_valid, minibatch_size)

        epoch_train_loss.append(train_loss)
        epoch_valid_loss.append(valid_loss)
        
        print(f'Epoch: {e+1:03d}/{num_epochs:03d} '
              f'| Train loss: {train_loss:.5f} '
              f'| Valid loss: {valid_loss:.5f} '
              f'| Train mse: {train_mse:.5f} '
              f'| Valid mse: {valid_mse:.5f} ')

    return epoch_train_loss, epoch_valid_loss

# %%
epochs=300
batch_size=500
lr=0.005

# %%
model=VAE(28*28, 400, 128, 10)
epoch_train_loss, epoch_valid_loss = train(model, X_train, y_train, X_valid, y_valid, num_epochs=epochs, minibatch_size=batch_size, learning_rate=lr)
# Out:
# Epoch: 001/300 | Train loss: 206.79119 | Valid loss: 207.10622 | Train mse: 0.06503 | Valid mse: 0.06513
# Epoch: 002/300 | Train loss: 192.88122 | Valid loss: 193.32676 | Train mse: 0.05827 | Valid mse: 0.05838
# Epoch: 003/300 | Train loss: 182.16940 | Valid loss: 182.42012 | Train mse: 0.05298 | Valid mse: 0.05302
# Epoch: 004/300 | Train loss: 171.21115 | Valid loss: 171.42116 | Train mse: 0.04722 | Valid mse: 0.04722
# Epoch: 005/300 | Train loss: 167.68164 | Valid loss: 167.90834 | Train mse: 0.04559 | Valid mse: 0.04554
# Epoch: 006/300 | Train loss: 160.32423 | Valid loss: 160.51571 | Train mse: 0.04275 | Valid mse: 0.04270
# Epoch: 007/300 | Train loss: 156.87509 | Valid loss: 157.00440 | Train mse: 0.04082 | Valid mse: 0.04076
# Epoch: 008/300 | Train loss: 152.91973 | Valid loss: 153.16694 | Train mse: 0.03933 | Valid mse: 0.03932
# Epoch: 009/300 | Train loss: 152.20914 | Valid loss: 152.36439 | Train mse: 0.03854 | Valid mse: 0.03852
# Epoch: 010/300 | Train loss: 147.42119 | Valid loss: 147.61149 | Train mse: 0.03634 | Valid mse: 0.03630
# Epoch: 011/300 | Train loss: 147.97174 | Valid loss: 148.13220 | Train mse: 0.03713 | Valid mse: 0.03710
# Epoch: 012/300 | Train loss: 149.40721 | Valid loss: 149.71296 | Train mse: 0.03731 | Valid mse: 0.03731
# Epoch: 013/300 | Train loss: 142.59074 | Valid loss: 142.91087 | Train mse: 0.03457 | Valid mse: 0.03461
# Epoch: 014/300 | Train loss: 141.72937 | Valid loss: 141.92602 | Train mse: 0.03387 | Valid mse: 0.03384
# Epoch: 015/300 | Train loss: 139.99674 | Valid loss: 140.17969 | Train mse: 0.03333 | Valid mse: 0.03333
# Epoch: 016/300 | Train loss: 139.10297 | Valid loss: 139.24615 | Train mse: 0.03259 | Valid mse: 0.03255
# Epoch: 017/300 | Train loss: 139.02968 | Valid loss: 139.27005 | Train mse: 0.03245 | Valid mse: 0.03245
# Epoch: 018/300 | Train loss: 136.52874 | Valid loss: 136.81659 | Train mse: 0.03121 | Valid mse: 0.03123
# Epoch: 019/300 | Train loss: 136.49453 | Valid loss: 136.77909 | Train mse: 0.03113 | Valid mse: 0.03115
# Epoch: 020/300 | Train loss: 138.60749 | Valid loss: 139.09005 | Train mse: 0.03280 | Valid mse: 0.03292
# Epoch: 021/300 | Train loss: 136.41238 | Valid loss: 136.68765 | Train mse: 0.03162 | Valid mse: 0.03162
# Epoch: 022/300 | Train loss: 135.81175 | Valid loss: 136.15909 | Train mse: 0.03082 | Valid mse: 0.03086
# Epoch: 023/300 | Train loss: 133.87342 | Valid loss: 134.13555 | Train mse: 0.02996 | Valid mse: 0.02996
# Epoch: 024/300 | Train loss: 133.60341 | Valid loss: 133.92515 | Train mse: 0.02985 | Valid mse: 0.02989
# Epoch: 025/300 | Train loss: 133.91359 | Valid loss: 134.39918 | Train mse: 0.03036 | Valid mse: 0.03045
# Epoch: 026/300 | Train loss: 131.90752 | Valid loss: 132.42512 | Train mse: 0.02930 | Valid mse: 0.02940
# Epoch: 027/300 | Train loss: 130.29589 | Valid loss: 130.68188 | Train mse: 0.02838 | Valid mse: 0.02845
# Epoch: 028/300 | Train loss: 130.80129 | Valid loss: 131.28384 | Train mse: 0.02870 | Valid mse: 0.02879
# Epoch: 029/300 | Train loss: 131.26105 | Valid loss: 131.74877 | Train mse: 0.02878 | Valid mse: 0.02888
# Epoch: 030/300 | Train loss: 131.97160 | Valid loss: 132.48314 | Train mse: 0.02962 | Valid mse: 0.02972
# Epoch: 031/300 | Train loss: 128.82170 | Valid loss: 129.30739 | Train mse: 0.02791 | Valid mse: 0.02800
# Epoch: 032/300 | Train loss: 129.63830 | Valid loss: 130.03947 | Train mse: 0.02817 | Valid mse: 0.02821
# Epoch: 033/300 | Train loss: 129.81269 | Valid loss: 130.26066 | Train mse: 0.02848 | Valid mse: 0.02856
# Epoch: 034/300 | Train loss: 128.58483 | Valid loss: 129.20049 | Train mse: 0.02789 | Valid mse: 0.02803
# Epoch: 035/300 | Train loss: 128.51818 | Valid loss: 128.91448 | Train mse: 0.02749 | Valid mse: 0.02756
# Epoch: 036/300 | Train loss: 127.78881 | Valid loss: 128.27955 | Train mse: 0.02726 | Valid mse: 0.02738
# Epoch: 037/300 | Train loss: 126.93158 | Valid loss: 127.32677 | Train mse: 0.02680 | Valid mse: 0.02686
# Epoch: 038/300 | Train loss: 127.56728 | Valid loss: 128.09350 | Train mse: 0.02701 | Valid mse: 0.02715
# Epoch: 039/300 | Train loss: 126.49505 | Valid loss: 127.16238 | Train mse: 0.02679 | Valid mse: 0.02697
# Epoch: 040/300 | Train loss: 127.71130 | Valid loss: 128.03334 | Train mse: 0.02715 | Valid mse: 0.02719
# Epoch: 041/300 | Train loss: 126.36019 | Valid loss: 126.87676 | Train mse: 0.02663 | Valid mse: 0.02675
# Epoch: 042/300 | Train loss: 126.89236 | Valid loss: 127.37550 | Train mse: 0.02688 | Valid mse: 0.02695
# Epoch: 043/300 | Train loss: 124.96091 | Valid loss: 125.51999 | Train mse: 0.02613 | Valid mse: 0.02626
# Epoch: 044/300 | Train loss: 124.86992 | Valid loss: 125.49805 | Train mse: 0.02591 | Valid mse: 0.02607
# Epoch: 045/300 | Train loss: 125.10701 | Valid loss: 125.72702 | Train mse: 0.02613 | Valid mse: 0.02628
# Epoch: 046/300 | Train loss: 124.59878 | Valid loss: 125.17665 | Train mse: 0.02564 | Valid mse: 0.02579
# Epoch: 047/300 | Train loss: 124.18106 | Valid loss: 124.67194 | Train mse: 0.02558 | Valid mse: 0.02570
# Epoch: 048/300 | Train loss: 124.90660 | Valid loss: 125.47232 | Train mse: 0.02585 | Valid mse: 0.02599
# Epoch: 049/300 | Train loss: 125.18440 | Valid loss: 125.77962 | Train mse: 0.02608 | Valid mse: 0.02621
# Epoch: 050/300 | Train loss: 123.34989 | Valid loss: 123.90098 | Train mse: 0.02521 | Valid mse: 0.02533
# Epoch: 051/300 | Train loss: 123.31716 | Valid loss: 123.85167 | Train mse: 0.02521 | Valid mse: 0.02533
# Epoch: 052/300 | Train loss: 123.96780 | Valid loss: 124.68318 | Train mse: 0.02567 | Valid mse: 0.02587
# Epoch: 053/300 | Train loss: 124.16991 | Valid loss: 124.92104 | Train mse: 0.02580 | Valid mse: 0.02599
# Epoch: 054/300 | Train loss: 123.18758 | Valid loss: 123.76394 | Train mse: 0.02508 | Valid mse: 0.02524
# Epoch: 055/300 | Train loss: 122.37216 | Valid loss: 122.95178 | Train mse: 0.02482 | Valid mse: 0.02496
# Epoch: 056/300 | Train loss: 123.03871 | Valid loss: 123.62660 | Train mse: 0.02506 | Valid mse: 0.02520
# Epoch: 057/300 | Train loss: 123.67371 | Valid loss: 124.38407 | Train mse: 0.02545 | Valid mse: 0.02565
# Epoch: 058/300 | Train loss: 121.94633 | Valid loss: 122.59747 | Train mse: 0.02451 | Valid mse: 0.02470
# Epoch: 059/300 | Train loss: 122.90718 | Valid loss: 123.63977 | Train mse: 0.02495 | Valid mse: 0.02514
# Epoch: 060/300 | Train loss: 121.68239 | Valid loss: 122.32877 | Train mse: 0.02441 | Valid mse: 0.02459
# Epoch: 061/300 | Train loss: 120.81156 | Valid loss: 121.49238 | Train mse: 0.02402 | Valid mse: 0.02421
# Epoch: 062/300 | Train loss: 121.11423 | Valid loss: 121.78708 | Train mse: 0.02419 | Valid mse: 0.02440
# Epoch: 063/300 | Train loss: 122.00642 | Valid loss: 122.66292 | Train mse: 0.02471 | Valid mse: 0.02488
# Epoch: 064/300 | Train loss: 121.72970 | Valid loss: 122.50245 | Train mse: 0.02442 | Valid mse: 0.02466
# Epoch: 065/300 | Train loss: 121.47390 | Valid loss: 122.18247 | Train mse: 0.02447 | Valid mse: 0.02467
# Epoch: 066/300 | Train loss: 122.90254 | Valid loss: 123.45585 | Train mse: 0.02507 | Valid mse: 0.02520
# Epoch: 067/300 | Train loss: 120.94289 | Valid loss: 121.58144 | Train mse: 0.02410 | Valid mse: 0.02428
# Epoch: 068/300 | Train loss: 119.60066 | Valid loss: 120.40453 | Train mse: 0.02342 | Valid mse: 0.02367
# Epoch: 069/300 | Train loss: 120.64450 | Valid loss: 121.36841 | Train mse: 0.02390 | Valid mse: 0.02410
# Epoch: 070/300 | Train loss: 120.67292 | Valid loss: 121.43779 | Train mse: 0.02396 | Valid mse: 0.02420
# Epoch: 071/300 | Train loss: 119.74532 | Valid loss: 120.47379 | Train mse: 0.02346 | Valid mse: 0.02367
# Epoch: 072/300 | Train loss: 120.70338 | Valid loss: 121.46650 | Train mse: 0.02396 | Valid mse: 0.02417
# Epoch: 073/300 | Train loss: 120.49498 | Valid loss: 121.28205 | Train mse: 0.02390 | Valid mse: 0.02412
# Epoch: 074/300 | Train loss: 118.90049 | Valid loss: 119.63369 | Train mse: 0.02316 | Valid mse: 0.02336
# Epoch: 075/300 | Train loss: 119.21873 | Valid loss: 119.94654 | Train mse: 0.02329 | Valid mse: 0.02349
# Epoch: 076/300 | Train loss: 119.60761 | Valid loss: 120.38809 | Train mse: 0.02344 | Valid mse: 0.02369
# Epoch: 077/300 | Train loss: 118.97366 | Valid loss: 119.72024 | Train mse: 0.02311 | Valid mse: 0.02333
# Epoch: 078/300 | Train loss: 119.29798 | Valid loss: 120.15453 | Train mse: 0.02328 | Valid mse: 0.02354
# Epoch: 079/300 | Train loss: 119.38653 | Valid loss: 120.21220 | Train mse: 0.02332 | Valid mse: 0.02358
# Epoch: 080/300 | Train loss: 117.97506 | Valid loss: 118.84948 | Train mse: 0.02265 | Valid mse: 0.02292
# Epoch: 081/300 | Train loss: 118.79124 | Valid loss: 119.66034 | Train mse: 0.02306 | Valid mse: 0.02330
# Epoch: 082/300 | Train loss: 119.40480 | Valid loss: 120.40396 | Train mse: 0.02334 | Valid mse: 0.02365
# Epoch: 083/300 | Train loss: 119.90995 | Valid loss: 120.66342 | Train mse: 0.02369 | Valid mse: 0.02391
# Epoch: 084/300 | Train loss: 119.40406 | Valid loss: 120.02407 | Train mse: 0.02320 | Valid mse: 0.02337
# Epoch: 085/300 | Train loss: 119.00508 | Valid loss: 119.88064 | Train mse: 0.02311 | Valid mse: 0.02338
# Epoch: 086/300 | Train loss: 118.53592 | Valid loss: 119.47650 | Train mse: 0.02288 | Valid mse: 0.02318
# Epoch: 087/300 | Train loss: 119.56631 | Valid loss: 120.27082 | Train mse: 0.02329 | Valid mse: 0.02350
# Epoch: 088/300 | Train loss: 117.95474 | Valid loss: 118.77345 | Train mse: 0.02256 | Valid mse: 0.02280
# Epoch: 089/300 | Train loss: 117.85283 | Valid loss: 118.60191 | Train mse: 0.02248 | Valid mse: 0.02272
# Epoch: 090/300 | Train loss: 118.14278 | Valid loss: 118.92345 | Train mse: 0.02264 | Valid mse: 0.02286
# Epoch: 091/300 | Train loss: 119.58469 | Valid loss: 120.35174 | Train mse: 0.02320 | Valid mse: 0.02346
# Epoch: 092/300 | Train loss: 117.68565 | Valid loss: 118.51658 | Train mse: 0.02238 | Valid mse: 0.02264
# Epoch: 093/300 | Train loss: 117.66987 | Valid loss: 118.57124 | Train mse: 0.02243 | Valid mse: 0.02272
# Epoch: 094/300 | Train loss: 117.21066 | Valid loss: 118.25368 | Train mse: 0.02221 | Valid mse: 0.02254
# Epoch: 095/300 | Train loss: 118.23151 | Valid loss: 118.99967 | Train mse: 0.02258 | Valid mse: 0.02281
# Epoch: 096/300 | Train loss: 119.45764 | Valid loss: 120.29645 | Train mse: 0.02316 | Valid mse: 0.02344
# Epoch: 097/300 | Train loss: 116.34835 | Valid loss: 117.17579 | Train mse: 0.02176 | Valid mse: 0.02201
# Epoch: 098/300 | Train loss: 119.10539 | Valid loss: 120.20704 | Train mse: 0.02310 | Valid mse: 0.02346
# Epoch: 099/300 | Train loss: 115.89404 | Valid loss: 116.74805 | Train mse: 0.02154 | Valid mse: 0.02179
# Epoch: 100/300 | Train loss: 118.51134 | Valid loss: 119.56750 | Train mse: 0.02275 | Valid mse: 0.02307
# Epoch: 101/300 | Train loss: 115.70272 | Valid loss: 116.68102 | Train mse: 0.02146 | Valid mse: 0.02178
# Epoch: 102/300 | Train loss: 115.84912 | Valid loss: 116.77306 | Train mse: 0.02148 | Valid mse: 0.02178
# Epoch: 103/300 | Train loss: 116.16544 | Valid loss: 117.05121 | Train mse: 0.02169 | Valid mse: 0.02197
# Epoch: 104/300 | Train loss: 117.09291 | Valid loss: 117.99224 | Train mse: 0.02196 | Valid mse: 0.02226
# Epoch: 105/300 | Train loss: 116.52728 | Valid loss: 117.45703 | Train mse: 0.02186 | Valid mse: 0.02215
# Epoch: 106/300 | Train loss: 115.53108 | Valid loss: 116.50454 | Train mse: 0.02127 | Valid mse: 0.02159
# Epoch: 107/300 | Train loss: 117.92180 | Valid loss: 119.05377 | Train mse: 0.02243 | Valid mse: 0.02279
# Epoch: 108/300 | Train loss: 116.65147 | Valid loss: 117.50865 | Train mse: 0.02179 | Valid mse: 0.02207
# Epoch: 109/300 | Train loss: 116.78875 | Valid loss: 117.61207 | Train mse: 0.02191 | Valid mse: 0.02217
# Epoch: 110/300 | Train loss: 117.11452 | Valid loss: 118.07960 | Train mse: 0.02205 | Valid mse: 0.02237
# Epoch: 111/300 | Train loss: 116.67602 | Valid loss: 117.62320 | Train mse: 0.02193 | Valid mse: 0.02223
# Epoch: 112/300 | Train loss: 116.30072 | Valid loss: 117.13727 | Train mse: 0.02163 | Valid mse: 0.02190
# Epoch: 113/300 | Train loss: 115.43501 | Valid loss: 116.41745 | Train mse: 0.02128 | Valid mse: 0.02160
# Epoch: 114/300 | Train loss: 115.33488 | Valid loss: 116.56661 | Train mse: 0.02129 | Valid mse: 0.02172
# Epoch: 115/300 | Train loss: 115.76858 | Valid loss: 116.89157 | Train mse: 0.02142 | Valid mse: 0.02179
# Epoch: 116/300 | Train loss: 116.73322 | Valid loss: 117.75394 | Train mse: 0.02187 | Valid mse: 0.02219
# Epoch: 117/300 | Train loss: 115.27522 | Valid loss: 116.22879 | Train mse: 0.02125 | Valid mse: 0.02157
# Epoch: 118/300 | Train loss: 114.25674 | Valid loss: 115.27121 | Train mse: 0.02066 | Valid mse: 0.02100
# Epoch: 119/300 | Train loss: 115.00761 | Valid loss: 116.08149 | Train mse: 0.02112 | Valid mse: 0.02147
# Epoch: 120/300 | Train loss: 115.91082 | Valid loss: 116.82329 | Train mse: 0.02145 | Valid mse: 0.02176
# Epoch: 121/300 | Train loss: 114.90487 | Valid loss: 115.88340 | Train mse: 0.02107 | Valid mse: 0.02139
# Epoch: 122/300 | Train loss: 114.72157 | Valid loss: 115.67257 | Train mse: 0.02094 | Valid mse: 0.02124
# Epoch: 123/300 | Train loss: 114.42420 | Valid loss: 115.29493 | Train mse: 0.02079 | Valid mse: 0.02107
# Epoch: 124/300 | Train loss: 114.56248 | Valid loss: 115.75517 | Train mse: 0.02096 | Valid mse: 0.02138
# Epoch: 125/300 | Train loss: 115.44517 | Valid loss: 116.34238 | Train mse: 0.02132 | Valid mse: 0.02162
# Epoch: 126/300 | Train loss: 115.80576 | Valid loss: 116.80917 | Train mse: 0.02138 | Valid mse: 0.02171
# Epoch: 127/300 | Train loss: 116.20019 | Valid loss: 117.28215 | Train mse: 0.02162 | Valid mse: 0.02201
# Epoch: 128/300 | Train loss: 114.61668 | Valid loss: 115.69525 | Train mse: 0.02087 | Valid mse: 0.02121
# Epoch: 129/300 | Train loss: 114.26630 | Valid loss: 115.24426 | Train mse: 0.02070 | Valid mse: 0.02103
# Epoch: 130/300 | Train loss: 114.30703 | Valid loss: 115.40060 | Train mse: 0.02075 | Valid mse: 0.02110
# Epoch: 131/300 | Train loss: 114.68573 | Valid loss: 115.72004 | Train mse: 0.02089 | Valid mse: 0.02125
# Epoch: 132/300 | Train loss: 113.67280 | Valid loss: 114.80674 | Train mse: 0.02041 | Valid mse: 0.02078
# Epoch: 133/300 | Train loss: 113.46674 | Valid loss: 114.61415 | Train mse: 0.02039 | Valid mse: 0.02079
# Epoch: 134/300 | Train loss: 113.43777 | Valid loss: 114.49021 | Train mse: 0.02032 | Valid mse: 0.02069
# Epoch: 135/300 | Train loss: 114.15492 | Valid loss: 115.20070 | Train mse: 0.02057 | Valid mse: 0.02092
# Epoch: 136/300 | Train loss: 113.52423 | Valid loss: 114.68094 | Train mse: 0.02036 | Valid mse: 0.02074
# Epoch: 137/300 | Train loss: 114.27987 | Valid loss: 115.40304 | Train mse: 0.02075 | Valid mse: 0.02111
# Epoch: 138/300 | Train loss: 113.61864 | Valid loss: 114.72810 | Train mse: 0.02048 | Valid mse: 0.02085
# Epoch: 139/300 | Train loss: 113.73341 | Valid loss: 114.76998 | Train mse: 0.02044 | Valid mse: 0.02080
# Epoch: 140/300 | Train loss: 112.77011 | Valid loss: 113.89517 | Train mse: 0.02001 | Valid mse: 0.02037
# Epoch: 141/300 | Train loss: 115.04780 | Valid loss: 116.22262 | Train mse: 0.02104 | Valid mse: 0.02142
# Epoch: 142/300 | Train loss: 113.52386 | Valid loss: 114.59861 | Train mse: 0.02028 | Valid mse: 0.02065
# Epoch: 143/300 | Train loss: 113.52517 | Valid loss: 114.65967 | Train mse: 0.02034 | Valid mse: 0.02072
# Epoch: 144/300 | Train loss: 112.17484 | Valid loss: 113.40767 | Train mse: 0.01972 | Valid mse: 0.02018
# Epoch: 145/300 | Train loss: 113.61954 | Valid loss: 114.90049 | Train mse: 0.02040 | Valid mse: 0.02084
# Epoch: 146/300 | Train loss: 112.60636 | Valid loss: 113.84350 | Train mse: 0.01991 | Valid mse: 0.02033
# Epoch: 147/300 | Train loss: 112.54377 | Valid loss: 113.74892 | Train mse: 0.01992 | Valid mse: 0.02035
# Epoch: 148/300 | Train loss: 112.44944 | Valid loss: 113.66325 | Train mse: 0.01988 | Valid mse: 0.02030
# Epoch: 149/300 | Train loss: 113.11482 | Valid loss: 114.17168 | Train mse: 0.02017 | Valid mse: 0.02053
# Epoch: 150/300 | Train loss: 111.91822 | Valid loss: 113.10667 | Train mse: 0.01962 | Valid mse: 0.02004
# Epoch: 151/300 | Train loss: 112.44338 | Valid loss: 113.63698 | Train mse: 0.01987 | Valid mse: 0.02028
# Epoch: 152/300 | Train loss: 111.73724 | Valid loss: 112.84953 | Train mse: 0.01951 | Valid mse: 0.01988
# Epoch: 153/300 | Train loss: 112.81117 | Valid loss: 114.04971 | Train mse: 0.02001 | Valid mse: 0.02041
# Epoch: 154/300 | Train loss: 113.23113 | Valid loss: 114.49138 | Train mse: 0.02021 | Valid mse: 0.02063
# Epoch: 155/300 | Train loss: 112.86532 | Valid loss: 114.04052 | Train mse: 0.02011 | Valid mse: 0.02054
# Epoch: 156/300 | Train loss: 112.85370 | Valid loss: 113.99930 | Train mse: 0.02005 | Valid mse: 0.02046
# Epoch: 157/300 | Train loss: 112.42255 | Valid loss: 113.62574 | Train mse: 0.01978 | Valid mse: 0.02022
# Epoch: 158/300 | Train loss: 111.90556 | Valid loss: 113.01580 | Train mse: 0.01957 | Valid mse: 0.01995
# Epoch: 159/300 | Train loss: 113.36444 | Valid loss: 114.65205 | Train mse: 0.02026 | Valid mse: 0.02070
# Epoch: 160/300 | Train loss: 112.46466 | Valid loss: 113.72533 | Train mse: 0.01985 | Valid mse: 0.02028
# Epoch: 161/300 | Train loss: 112.98513 | Valid loss: 114.31924 | Train mse: 0.02011 | Valid mse: 0.02056
# Epoch: 162/300 | Train loss: 111.79194 | Valid loss: 112.90531 | Train mse: 0.01950 | Valid mse: 0.01989
# Epoch: 163/300 | Train loss: 111.10083 | Valid loss: 112.28123 | Train mse: 0.01920 | Valid mse: 0.01961
# Epoch: 164/300 | Train loss: 112.19477 | Valid loss: 113.27571 | Train mse: 0.01970 | Valid mse: 0.02008
# Epoch: 165/300 | Train loss: 111.63021 | Valid loss: 112.88339 | Train mse: 0.01945 | Valid mse: 0.01989
# Epoch: 166/300 | Train loss: 111.05677 | Valid loss: 112.31492 | Train mse: 0.01921 | Valid mse: 0.01964
# Epoch: 167/300 | Train loss: 111.52781 | Valid loss: 112.72342 | Train mse: 0.01944 | Valid mse: 0.01985
# Epoch: 168/300 | Train loss: 112.42872 | Valid loss: 113.81379 | Train mse: 0.01980 | Valid mse: 0.02027
# Epoch: 169/300 | Train loss: 110.56803 | Valid loss: 111.75972 | Train mse: 0.01897 | Valid mse: 0.01939
# Epoch: 170/300 | Train loss: 112.58991 | Valid loss: 113.95126 | Train mse: 0.01995 | Valid mse: 0.02042
# Epoch: 171/300 | Train loss: 111.69409 | Valid loss: 112.90296 | Train mse: 0.01947 | Valid mse: 0.01989
# Epoch: 172/300 | Train loss: 112.98599 | Valid loss: 114.14275 | Train mse: 0.02005 | Valid mse: 0.02047
# Epoch: 173/300 | Train loss: 112.54103 | Valid loss: 113.77304 | Train mse: 0.01987 | Valid mse: 0.02031
# Epoch: 174/300 | Train loss: 112.51664 | Valid loss: 113.60598 | Train mse: 0.01984 | Valid mse: 0.02022
# Epoch: 175/300 | Train loss: 111.20676 | Valid loss: 112.45502 | Train mse: 0.01925 | Valid mse: 0.01969
# Epoch: 176/300 | Train loss: 111.03010 | Valid loss: 112.40305 | Train mse: 0.01924 | Valid mse: 0.01973
# Epoch: 177/300 | Train loss: 111.92849 | Valid loss: 113.32109 | Train mse: 0.01967 | Valid mse: 0.02016
# Epoch: 178/300 | Train loss: 110.68637 | Valid loss: 111.96648 | Train mse: 0.01902 | Valid mse: 0.01949
# Epoch: 179/300 | Train loss: 110.93881 | Valid loss: 112.28999 | Train mse: 0.01915 | Valid mse: 0.01962
# Epoch: 180/300 | Train loss: 112.06173 | Valid loss: 113.34601 | Train mse: 0.01965 | Valid mse: 0.02009
# Epoch: 181/300 | Train loss: 112.06285 | Valid loss: 113.40005 | Train mse: 0.01960 | Valid mse: 0.02006
# Epoch: 182/300 | Train loss: 110.49608 | Valid loss: 111.74129 | Train mse: 0.01892 | Valid mse: 0.01938
# Epoch: 183/300 | Train loss: 111.26767 | Valid loss: 112.62025 | Train mse: 0.01928 | Valid mse: 0.01978
# Epoch: 184/300 | Train loss: 111.96169 | Valid loss: 113.46216 | Train mse: 0.01963 | Valid mse: 0.02015
# Epoch: 185/300 | Train loss: 110.45790 | Valid loss: 111.80409 | Train mse: 0.01891 | Valid mse: 0.01941
# Epoch: 186/300 | Train loss: 110.95292 | Valid loss: 112.39019 | Train mse: 0.01910 | Valid mse: 0.01963
# Epoch: 187/300 | Train loss: 110.43601 | Valid loss: 111.80131 | Train mse: 0.01889 | Valid mse: 0.01939
# Epoch: 188/300 | Train loss: 112.55719 | Valid loss: 114.08109 | Train mse: 0.01985 | Valid mse: 0.02037
# Epoch: 189/300 | Train loss: 111.63032 | Valid loss: 112.91914 | Train mse: 0.01945 | Valid mse: 0.01992
# Epoch: 190/300 | Train loss: 111.70328 | Valid loss: 113.07957 | Train mse: 0.01947 | Valid mse: 0.01996
# Epoch: 191/300 | Train loss: 110.67922 | Valid loss: 112.01531 | Train mse: 0.01899 | Valid mse: 0.01948
# Epoch: 192/300 | Train loss: 111.89825 | Valid loss: 113.49053 | Train mse: 0.01956 | Valid mse: 0.02010
# Epoch: 193/300 | Train loss: 111.14800 | Valid loss: 112.60621 | Train mse: 0.01922 | Valid mse: 0.01972
# Epoch: 194/300 | Train loss: 110.48112 | Valid loss: 111.85735 | Train mse: 0.01885 | Valid mse: 0.01933
# Epoch: 195/300 | Train loss: 110.26410 | Valid loss: 111.53042 | Train mse: 0.01878 | Valid mse: 0.01923
# Epoch: 196/300 | Train loss: 110.29937 | Valid loss: 111.80005 | Train mse: 0.01883 | Valid mse: 0.01936
# Epoch: 197/300 | Train loss: 110.97502 | Valid loss: 112.53288 | Train mse: 0.01911 | Valid mse: 0.01967
# Epoch: 198/300 | Train loss: 111.03611 | Valid loss: 112.44596 | Train mse: 0.01917 | Valid mse: 0.01966
# Epoch: 199/300 | Train loss: 110.56550 | Valid loss: 112.15186 | Train mse: 0.01892 | Valid mse: 0.01952
# Epoch: 200/300 | Train loss: 110.36079 | Valid loss: 111.83140 | Train mse: 0.01880 | Valid mse: 0.01932
# Epoch: 201/300 | Train loss: 110.30123 | Valid loss: 111.70392 | Train mse: 0.01882 | Valid mse: 0.01934
# Epoch: 202/300 | Train loss: 111.43352 | Valid loss: 112.69535 | Train mse: 0.01941 | Valid mse: 0.01987
# Epoch: 203/300 | Train loss: 110.10437 | Valid loss: 111.57332 | Train mse: 0.01874 | Valid mse: 0.01927
# Epoch: 204/300 | Train loss: 111.27895 | Valid loss: 112.72332 | Train mse: 0.01924 | Valid mse: 0.01974
# Epoch: 205/300 | Train loss: 109.53077 | Valid loss: 110.97507 | Train mse: 0.01842 | Valid mse: 0.01894
# Epoch: 206/300 | Train loss: 110.84699 | Valid loss: 112.30896 | Train mse: 0.01908 | Valid mse: 0.01963
# Epoch: 207/300 | Train loss: 110.34404 | Valid loss: 111.88336 | Train mse: 0.01884 | Valid mse: 0.01938
# Epoch: 208/300 | Train loss: 109.33193 | Valid loss: 110.69631 | Train mse: 0.01839 | Valid mse: 0.01890
# Epoch: 209/300 | Train loss: 110.41035 | Valid loss: 112.07986 | Train mse: 0.01886 | Valid mse: 0.01946
# Epoch: 210/300 | Train loss: 110.94499 | Valid loss: 112.36000 | Train mse: 0.01908 | Valid mse: 0.01960
# Epoch: 211/300 | Train loss: 109.16202 | Valid loss: 110.69656 | Train mse: 0.01830 | Valid mse: 0.01885
# Epoch: 212/300 | Train loss: 111.11295 | Valid loss: 112.54363 | Train mse: 0.01917 | Valid mse: 0.01970
# Epoch: 213/300 | Train loss: 109.92512 | Valid loss: 111.55654 | Train mse: 0.01862 | Valid mse: 0.01921
# Epoch: 214/300 | Train loss: 110.46003 | Valid loss: 112.05724 | Train mse: 0.01896 | Valid mse: 0.01955
# Epoch: 215/300 | Train loss: 109.14385 | Valid loss: 110.65430 | Train mse: 0.01833 | Valid mse: 0.01888
# Epoch: 216/300 | Train loss: 110.04948 | Valid loss: 111.63112 | Train mse: 0.01872 | Valid mse: 0.01927
# Epoch: 217/300 | Train loss: 110.37584 | Valid loss: 111.86238 | Train mse: 0.01886 | Valid mse: 0.01940
# Epoch: 218/300 | Train loss: 109.93298 | Valid loss: 111.28280 | Train mse: 0.01868 | Valid mse: 0.01918
# Epoch: 219/300 | Train loss: 110.20477 | Valid loss: 111.83249 | Train mse: 0.01876 | Valid mse: 0.01933
# Epoch: 220/300 | Train loss: 109.35253 | Valid loss: 110.78037 | Train mse: 0.01837 | Valid mse: 0.01890
# Epoch: 221/300 | Train loss: 111.81924 | Valid loss: 113.43359 | Train mse: 0.01949 | Valid mse: 0.02003
# Epoch: 222/300 | Train loss: 109.81238 | Valid loss: 111.30563 | Train mse: 0.01861 | Valid mse: 0.01915
# Epoch: 223/300 | Train loss: 109.49681 | Valid loss: 110.93777 | Train mse: 0.01842 | Valid mse: 0.01896
# Epoch: 224/300 | Train loss: 109.24106 | Valid loss: 110.85611 | Train mse: 0.01836 | Valid mse: 0.01896
# Epoch: 225/300 | Train loss: 110.28351 | Valid loss: 111.94596 | Train mse: 0.01878 | Valid mse: 0.01939
# Epoch: 226/300 | Train loss: 111.86946 | Valid loss: 113.41152 | Train mse: 0.01943 | Valid mse: 0.01997
# Epoch: 227/300 | Train loss: 110.16176 | Valid loss: 111.94263 | Train mse: 0.01875 | Valid mse: 0.01941
# Epoch: 228/300 | Train loss: 109.50609 | Valid loss: 111.13638 | Train mse: 0.01846 | Valid mse: 0.01905
# Epoch: 229/300 | Train loss: 109.10020 | Valid loss: 110.60845 | Train mse: 0.01828 | Valid mse: 0.01882
# Epoch: 230/300 | Train loss: 109.34008 | Valid loss: 110.81826 | Train mse: 0.01839 | Valid mse: 0.01895
# Epoch: 231/300 | Train loss: 108.37793 | Valid loss: 109.94483 | Train mse: 0.01792 | Valid mse: 0.01850
# Epoch: 232/300 | Train loss: 109.39903 | Valid loss: 110.96954 | Train mse: 0.01841 | Valid mse: 0.01900
# Epoch: 233/300 | Train loss: 108.19848 | Valid loss: 109.91189 | Train mse: 0.01786 | Valid mse: 0.01851
# Epoch: 234/300 | Train loss: 109.63007 | Valid loss: 111.32330 | Train mse: 0.01851 | Valid mse: 0.01912
# Epoch: 235/300 | Train loss: 108.84763 | Valid loss: 110.41005 | Train mse: 0.01816 | Valid mse: 0.01874
# Epoch: 236/300 | Train loss: 109.94080 | Valid loss: 111.74789 | Train mse: 0.01860 | Valid mse: 0.01924
# Epoch: 237/300 | Train loss: 110.46791 | Valid loss: 112.09280 | Train mse: 0.01884 | Valid mse: 0.01942
# Epoch: 238/300 | Train loss: 108.10136 | Valid loss: 109.79786 | Train mse: 0.01779 | Valid mse: 0.01840
# Epoch: 239/300 | Train loss: 110.11854 | Valid loss: 111.72760 | Train mse: 0.01867 | Valid mse: 0.01926
# Epoch: 240/300 | Train loss: 108.76327 | Valid loss: 110.34332 | Train mse: 0.01810 | Valid mse: 0.01868
# Epoch: 241/300 | Train loss: 108.90673 | Valid loss: 110.41091 | Train mse: 0.01822 | Valid mse: 0.01875
# Epoch: 242/300 | Train loss: 108.44464 | Valid loss: 110.02148 | Train mse: 0.01799 | Valid mse: 0.01857
# Epoch: 243/300 | Train loss: 108.16366 | Valid loss: 109.91939 | Train mse: 0.01777 | Valid mse: 0.01842
# Epoch: 244/300 | Train loss: 109.53993 | Valid loss: 111.35272 | Train mse: 0.01844 | Valid mse: 0.01911
# Epoch: 245/300 | Train loss: 108.54466 | Valid loss: 110.21874 | Train mse: 0.01802 | Valid mse: 0.01866
# Epoch: 246/300 | Train loss: 109.48041 | Valid loss: 111.16703 | Train mse: 0.01836 | Valid mse: 0.01898
# Epoch: 247/300 | Train loss: 109.19123 | Valid loss: 111.02292 | Train mse: 0.01830 | Valid mse: 0.01898
# Epoch: 248/300 | Train loss: 109.87192 | Valid loss: 111.57726 | Train mse: 0.01860 | Valid mse: 0.01923
# Epoch: 249/300 | Train loss: 110.01503 | Valid loss: 111.81737 | Train mse: 0.01865 | Valid mse: 0.01931
# Epoch: 250/300 | Train loss: 108.55667 | Valid loss: 110.34508 | Train mse: 0.01796 | Valid mse: 0.01862
# Epoch: 251/300 | Train loss: 108.98407 | Valid loss: 110.56015 | Train mse: 0.01816 | Valid mse: 0.01877
# Epoch: 252/300 | Train loss: 109.73457 | Valid loss: 111.41390 | Train mse: 0.01850 | Valid mse: 0.01916
# Epoch: 253/300 | Train loss: 108.39579 | Valid loss: 110.06744 | Train mse: 0.01797 | Valid mse: 0.01858
# Epoch: 254/300 | Train loss: 109.53913 | Valid loss: 111.22406 | Train mse: 0.01849 | Valid mse: 0.01911
# Epoch: 255/300 | Train loss: 108.08516 | Valid loss: 109.85672 | Train mse: 0.01781 | Valid mse: 0.01846
# Epoch: 256/300 | Train loss: 108.67926 | Valid loss: 110.54350 | Train mse: 0.01803 | Valid mse: 0.01868
# Epoch: 257/300 | Train loss: 108.41517 | Valid loss: 109.97795 | Train mse: 0.01793 | Valid mse: 0.01852
# Epoch: 258/300 | Train loss: 107.62466 | Valid loss: 109.19695 | Train mse: 0.01754 | Valid mse: 0.01811
# Epoch: 259/300 | Train loss: 109.85068 | Valid loss: 111.64496 | Train mse: 0.01852 | Valid mse: 0.01920
# Epoch: 260/300 | Train loss: 108.25369 | Valid loss: 109.95141 | Train mse: 0.01787 | Valid mse: 0.01851
# Epoch: 261/300 | Train loss: 107.97674 | Valid loss: 109.76670 | Train mse: 0.01774 | Valid mse: 0.01840
# Epoch: 262/300 | Train loss: 107.97382 | Valid loss: 109.68822 | Train mse: 0.01770 | Valid mse: 0.01834
# Epoch: 263/300 | Train loss: 108.65174 | Valid loss: 110.38367 | Train mse: 0.01801 | Valid mse: 0.01864
# Epoch: 264/300 | Train loss: 107.65041 | Valid loss: 109.37044 | Train mse: 0.01752 | Valid mse: 0.01818
# Epoch: 265/300 | Train loss: 110.97687 | Valid loss: 112.58406 | Train mse: 0.01905 | Valid mse: 0.01966
# Epoch: 266/300 | Train loss: 108.24609 | Valid loss: 109.83774 | Train mse: 0.01785 | Valid mse: 0.01844
# Epoch: 267/300 | Train loss: 109.50288 | Valid loss: 111.14254 | Train mse: 0.01836 | Valid mse: 0.01899
# Epoch: 268/300 | Train loss: 107.92999 | Valid loss: 109.67678 | Train mse: 0.01766 | Valid mse: 0.01831
# Epoch: 269/300 | Train loss: 108.55805 | Valid loss: 110.22770 | Train mse: 0.01795 | Valid mse: 0.01858
# Epoch: 270/300 | Train loss: 109.90367 | Valid loss: 111.55397 | Train mse: 0.01858 | Valid mse: 0.01920
# Epoch: 271/300 | Train loss: 109.54331 | Valid loss: 111.32081 | Train mse: 0.01846 | Valid mse: 0.01910
# Epoch: 272/300 | Train loss: 107.60717 | Valid loss: 109.38652 | Train mse: 0.01756 | Valid mse: 0.01822
# Epoch: 273/300 | Train loss: 107.66259 | Valid loss: 109.42962 | Train mse: 0.01758 | Valid mse: 0.01824
# Epoch: 274/300 | Train loss: 108.96663 | Valid loss: 110.72242 | Train mse: 0.01817 | Valid mse: 0.01882
# Epoch: 275/300 | Train loss: 108.13249 | Valid loss: 109.92305 | Train mse: 0.01775 | Valid mse: 0.01840
# Epoch: 276/300 | Train loss: 108.16160 | Valid loss: 109.91741 | Train mse: 0.01782 | Valid mse: 0.01848
# Epoch: 277/300 | Train loss: 107.85826 | Valid loss: 109.60262 | Train mse: 0.01765 | Valid mse: 0.01832
# Epoch: 278/300 | Train loss: 108.34375 | Valid loss: 110.11391 | Train mse: 0.01786 | Valid mse: 0.01853
# Epoch: 279/300 | Train loss: 107.99112 | Valid loss: 109.66035 | Train mse: 0.01773 | Valid mse: 0.01834
# Epoch: 280/300 | Train loss: 107.05711 | Valid loss: 108.93911 | Train mse: 0.01733 | Valid mse: 0.01804
# Epoch: 281/300 | Train loss: 107.25822 | Valid loss: 108.98955 | Train mse: 0.01737 | Valid mse: 0.01803
# Epoch: 282/300 | Train loss: 107.78325 | Valid loss: 109.62623 | Train mse: 0.01766 | Valid mse: 0.01834
# Epoch: 283/300 | Train loss: 108.06788 | Valid loss: 109.91143 | Train mse: 0.01774 | Valid mse: 0.01844
# Epoch: 284/300 | Train loss: 108.50437 | Valid loss: 110.27617 | Train mse: 0.01797 | Valid mse: 0.01863
# Epoch: 285/300 | Train loss: 107.46356 | Valid loss: 109.31812 | Train mse: 0.01750 | Valid mse: 0.01819
# Epoch: 286/300 | Train loss: 108.48377 | Valid loss: 110.36615 | Train mse: 0.01790 | Valid mse: 0.01857
# Epoch: 287/300 | Train loss: 109.04481 | Valid loss: 110.84718 | Train mse: 0.01819 | Valid mse: 0.01886
# Epoch: 288/300 | Train loss: 108.73421 | Valid loss: 110.51111 | Train mse: 0.01805 | Valid mse: 0.01871
# Epoch: 289/300 | Train loss: 108.20039 | Valid loss: 110.06273 | Train mse: 0.01782 | Valid mse: 0.01850
# Epoch: 290/300 | Train loss: 107.55524 | Valid loss: 109.40088 | Train mse: 0.01754 | Valid mse: 0.01820
# Epoch: 291/300 | Train loss: 108.57772 | Valid loss: 110.30012 | Train mse: 0.01800 | Valid mse: 0.01866
# Epoch: 292/300 | Train loss: 108.62231 | Valid loss: 110.63218 | Train mse: 0.01803 | Valid mse: 0.01877
# Epoch: 293/300 | Train loss: 108.78349 | Valid loss: 110.65468 | Train mse: 0.01808 | Valid mse: 0.01876
# Epoch: 294/300 | Train loss: 107.82065 | Valid loss: 109.68509 | Train mse: 0.01765 | Valid mse: 0.01838
# Epoch: 295/300 | Train loss: 107.28250 | Valid loss: 109.04337 | Train mse: 0.01741 | Valid mse: 0.01809
# Epoch: 296/300 | Train loss: 107.02895 | Valid loss: 108.86946 | Train mse: 0.01726 | Valid mse: 0.01796
# Epoch: 297/300 | Train loss: 106.90776 | Valid loss: 108.87925 | Train mse: 0.01717 | Valid mse: 0.01791
# Epoch: 298/300 | Train loss: 107.63355 | Valid loss: 109.71843 | Train mse: 0.01758 | Valid mse: 0.01835
# Epoch: 299/300 | Train loss: 109.61491 | Valid loss: 111.64703 | Train mse: 0.01839 | Valid mse: 0.01912
# Epoch: 300/300 | Train loss: 107.01400 | Valid loss: 108.95710 | Train mse: 0.01723 | Valid mse: 0.01795

# %%
import matplotlib.pyplot as plt

plt.plot(range(len(epoch_train_loss)), epoch_train_loss,
         label='Training')
plt.plot(range(len(epoch_valid_loss)), epoch_valid_loss,
         label='Validation')
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.legend(loc='upper right')
plt.tight_layout()
plt.show()

# %%
import pickle

with open('VAE_MNIST.p', 'wb') as file:
    pickle.dump(model, file)
    pickle.dump(epoch_train_loss, file)
    pickle.dump(epoch_valid_loss, file)

# %%
n=np.random.randint(0,10000,1)
n=3001

plt.figure(figsize=(2, 2)) # original data
plt.imshow(X_test[n,:].reshape(28,28),cmap='Greys')
plt.axis('off')
plt.show() 

fig, ax = plt.subplots(nrows=3, ncols=10, sharex=True, sharey=True)
ax = ax.flatten()
for i in range(30):
    _, _, _, _, _, _, _, _, _, _, _, pred, _ = model.forward(X_test[n,:])
    img = pred.reshape(28, 28)
    ax[i].imshow(img, cmap='Greys')

ax[0].set_xticks([])
ax[0].set_yticks([])
plt.tight_layout()
plt.show()

# %%
n
# Out:
# 3001
